# %%
import pandas as pd

url = 'https://www.finanz.ru/valyuty/v-realnom-vremeni'
ds = pd.read_html(url, encoding='utf-8')

# %%
ds[0]
# Out:
#      0       1      2        3       4      5        6       7      8   \
# 0  ММВБ   3 837   0,4%   Nasdaq  14 272   0,1%  Биткойн  32 596  -3,1%
# 1   РТС   1 666   1,3%   S&P500   4 242  -0,1%    Нефть     752  -0,3%
# 2   Dow  33 874  -0,2%  FTSE100   7 074  -0,2%   Золото   1 776  -0,2%
#
#         9       10     11
# 0  USD/RUB  725595  -0,1%
# 1  EUR/RUB  865110  -0,1%
# 2  EUR/USD   11924   0,0%

# %%
ds[1]
# Out:
#     Unnamed: 0              Рубль  Предложение  Спрос  Предыдущее закрытие  \
# 0          NaN            GBP/RUB      1007651      -              1014084
# 1          NaN            EUR/RUB       863009      -               866275
# 2          NaN            USD/RUB       723144      -               726275
# 3          NaN            JPY/RUB        06525      -                06545
# 4          NaN            CNY/RUB       111735      -               112182
# 5          NaN            CHF/RUB       787670      -               790966
# 6          NaN               Евро  Предложение  Спрос  Предыдущее закрытие
# 7          NaN            EUR/USD        11935      -                11928
# 8          NaN            EUR/GBP        08567      -                08543
# 9          NaN            EUR/JPY      1322850      -              1323600
# 10         NaN            EUR/CHF        10959      -                10952
# ...
